# %% [markdown]
# # CLASS/POLICY BASED ROUTING USING P4 SWITCHES

# %% [markdown]
# ## RUN EXPERIMENT

# %% [markdown]
# ## SETUP FABRIC CONFIGURATION

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager()
fablib.show_config()

# set appropriate permission on your keys
# !chmod 600 {fablib.get_bastion_key_filename()}
# !chmod 600 {fablib.get_default_slice_private_key_file()}
# Out:
# <style type="text/css">
# #T_b5dc5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b5dc5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b5dc5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_b5dc5_row0_col0, #T_b5dc5_row0_col1, #T_b5dc5_row1_col0, #T_b5dc5_row1_col1, #T_b5dc5_row2_col0, #T_b5dc5_row2_col1, #T_b5dc5_row3_col0, #T_b5dc5_row3_col1, #T_b5dc5_row4_col0, #T_b5dc5_row4_col1, #T_b5dc5_row5_col0, #T_b5dc5_row5_col1, #T_b5dc5_row6_col0, #T_b5dc5_row6_col1, #T_b5dc5_row7_col0, #T_b5dc5_row7_col1, #T_b5dc5_row8_col0, #T_b5dc5_row8_col1, #T_b5dc5_row9_col0, #T_b5dc5_row9_col1, #T_b5dc5_row10_col0, #T_b5dc5_row10_col1, #T_b5dc5_row11_col0, #T_b5dc5_row11_col1, #T_b5dc5_row12_col0, #T_b5dc5_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_b5dc5">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
import json
import traceback
import os

SLICENAME="Class/Policy-based-Routing_" + os.getenv('NB_USER')


try:
    slice = fablib.get_slice(SLICENAME)
    print("You already have a slice named %s." % SLICENAME)
    print(slice)
except:
    slice = fablib.new_slice(name=SLICENAME)
    print("You will need to create a %s slice." % SLICENAME)
# Out:
# You will need to create a Class/Policy-based-Routing_vsunda21 slice.

# %% [markdown]
# ## SITE SELECTION

# %%
exp_requires = {'core': 4*3, 'nic': 4}
while True:
    site_name = fablib.get_random_site()
    site_name = 'DALL'
    if ( (fablib.resources.get_core_available(site_name) > 1.2*exp_requires['core']) and
        (fablib.resources.get_component_available(site_name, 'SharedNIC-ConnectX-6') > 1.2**exp_requires['nic']) ):
        break

fablib.show_site(site_name)
# Out:
# <style type="text/css">
# #T_0afb0 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0afb0 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0afb0 caption {
#   text-align: center;
#   font-size: 150%;
# }
# ...

# %%
# this cell sets up hosts and routers
node_names = ["Vignesh_Source", "switch1", "Vignesh_Receiver"]
for n in node_names:
    slice.add_node(name=n, site=site_name, cores=4, disk=100, image='default_ubuntu_20')

# %%
# this cell sets up the network links
nets = [
    {"name": "net0",  "nodes": ["Vignesh_Source", "switch1"]},
    {"name": "net1",  "nodes": ["switch1", "Vignesh_Receiver"]},
    {"name": "net2",  "nodes": ["switch1", "Vignesh_Receiver"]}
]
for n in nets:
    ifaces = [slice.get_node(node).add_component(model="NIC_Basic", name=n["name"]).get_interfaces()[0] for node in n['nodes'] ]
    slice.add_l2network(name=n["name"], type='L2Bridge', interfaces=ifaces)

# %%
slice.submit()
# Out:
# Retry: 8, Time: 241 sec
# <style type="text/css">
# #T_4e35e tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4e35e tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4e35e caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_4e35e_row0_col0, #T_4e35e_row0_col1, #T_4e35e_row1_col0, #T_4e35e_row1_col1, #T_4e35e_row2_col0, #T_4e35e_row2_col1, #T_4e35e_row3_col0, #T_4e35e_row3_col1, #T_4e35e_row4_col0, #T_4e35e_row4_col1, #T_4e35e_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_4e35e_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_4e35e">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4e35e_row0_col0" class="data row0 col0" >ID</td>
# ...

# %%
slice.wait_ssh(progress=True)
# Out:
# Waiting for slice . Slice state: StableOK
# Waiting for ssh in slice . ssh successful
# True

# %%
for node in slice.get_nodes():
    print(f"{node}")
# Out:
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# ID                 36ed2d89-90e4-4d88-9691-39d308e58364
# Name               Vignesh_Source
# Cores              4
# RAM                8
# Disk               100
# Image              default_ubuntu_20
# Image Type         qcow2
# Host               dall-w3.fabric-testbed.net
# Site               DALL
# Management IP      2001:400:a100:3000:f816:3eff:fece:403a
# Reservation State  Active
# Error Message
# SSH Command        ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3000:f816:3eff:fece:403a
# -----------------  --------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# variables specific to this slice
Vignesh_Source_IP = str(slice.get_node("Vignesh_Source").get_management_ip())
Vignesh_Source_USER =  str(slice.get_node("Vignesh_Source").get_username())
Vignesh_Source_IFACE_V = slice.get_node("Vignesh_Source").get_interfaces()[0].get_os_interface()

Vignesh_Receiver_IP = str(slice.get_node("Vignesh_Receiver").get_management_ip())
Vignesh_Receiver_USER =  str(slice.get_node("Vignesh_Receiver").get_username())
Vignesh_Receiver_IFACE_1 = slice.get_node("Vignesh_Receiver").get_component("net1").get_interfaces()[0].get_os_interface()
Vignesh_Receiver_IFACE_2 = slice.get_node("Vignesh_Receiver").get_component("net2").get_interfaces()[0].get_os_interface()


switch1_IP = str(slice.get_node("switch1").get_management_ip())
switch1_USER =  str(slice.get_node("switch1").get_username())
switch1_IFACE_0 = slice.get_node("switch1").get_component("net0").get_interfaces()[0].get_os_interface()
switch1_IFACE_1 = slice.get_node("switch1").get_component("net1").get_interfaces()[0].get_os_interface()
switch1_IFACE_2 = slice.get_node("switch1").get_component("net2").get_interfaces()[0].get_os_interface()

FABRIC_SLICE_PRIVATE_KEY_FILE = fablib.get_default_slice_private_key_file
FABRIC_BASTION_USERNAME = fablib.get_bastion_username()
FABRIC_BASTION_HOST = fablib.get_bastion_public_addr()

SSH_CMD_Vignesh_Source=slice.get_node('Vignesh_Source').get_ssh_command()
SSH_CMD_Vignesh_Receiver=slice.get_node('Vignesh_Receiver').get_ssh_command()
SSH_CMD_ROUTER1=slice.get_node('switch1').get_ssh_command()

# %% [markdown]
# ## ONE TIME SETUP

# %%
from ipaddress import ip_address, IPv4Address, IPv4Network

if_conf = {
    "Vignesh_Source-net0-p1":   {"addr": "192.168.0.1", "subnet": "192.168.0.0/24"},
    "switch1-net0-p1":  {"addr": "192.168.0.2", "subnet": "192.168.0.0/24"},
    "switch1-net1-p1":  {"addr": "192.168.1.1", "subnet": "192.168.1.0/24"},
    "switch1-net2-p1":  {"addr": "192.168.1.2", "subnet": "192.168.1.0/24"},
    "Vignesh_Receiver-net1-p1":  {"addr": "192.168.1.3", "subnet": "192.168.1.0/24"},
    "Vignesh_Receiver-net2-p1":  {"addr": "192.168.1.4", "subnet": "192.168.1.0/24"}
}

for iface in slice.get_interfaces():
    if_name = iface.get_name()
    iface.ip_addr_add(addr=if_conf[if_name]['addr'], subnet=IPv4Network(if_conf[if_name]['subnet']))

# %%
rt_conf = [
    {"name": "Vignesh_Source",   "addr": "192.168.1.0/24", "gw": "192.168.0.2"},
    {"name": "Vignesh_Receiver",   "addr": "192.168.0.0/24", "gw": "192.168.1.1"},
    {"name": "Vignesh_Receiver",   "addr": "192.168.0.0/24", "gw": "192.168.1.2"}
    
]
for rt in rt_conf:
    slice.get_node(name=rt['name']).ip_route_add(subnet=IPv4Network(rt['addr']), gateway=rt['gw'])

# %%
for n in ['switch1']:
    slice.get_node(name=n).execute("sudo sysctl -w net.ipv4.ip_forward=1")
# Out:
# net.ipv4.ip_forward = 1

# %%
for iface in slice.get_interfaces():
    iface.ip_link_up()

# %%
for node in ["Vignesh_Source", "Vignesh_Receiver", "switch1"]:
    slice.get_node(node).execute("sudo sed -i '/nameserver/d' /etc/resolv.conf")
    slice.get_node(node).execute("echo nameserver 2a00:1098:2c::1 | sudo tee -a /etc/resolv.conf")
    slice.get_node(node).execute("echo nameserver 2a01:4f8:c2c:123f::1 | sudo tee -a /etc/resolv.conf")
    slice.get_node(node).execute("echo nameserver 2a00:1098:2b::1 | sudo tee -a /etc/resolv.conf")
    slice.get_node(node).execute('echo "127.0.0.1 $(hostname -s)" | sudo tee -a /etc/hosts')
# Out:
# nameserver 2a00:1098:2c::1
# nameserver 2a01:4f8:c2c:123f::1
# nameserver 2a00:1098:2b::1
# 127.0.0.1 36ed2d89-90e4-4d88-9691-39d308e58364-vignesh-source
# nameserver 2a00:1098:2c::1
# nameserver 2a01:4f8:c2c:123f::1
# nameserver 2a00:1098:2b::1
# 127.0.0.1 0cd38f4e-5efd-41f5-8ca7-27b8059f0d2f-vignesh-receiver
# nameserver 2a00:1098:2c::1
# nameserver 2a01:4f8:c2c:123f::1
# nameserver 2a00:1098:2b::1
# 127.0.0.1 a95bef47-a6e9-4dfe-ab95-4f7cc9b894a3-switch1

# %%
for n in ['Vignesh_Source', 'switch1','Vignesh_Receiver']:
    slice.get_node(name=n).execute("sudo apt update; sudo apt -y install net-tools iperf3 moreutils", quiet=True)

# %%
for n in ['Vignesh_Source', 'switch1','Vignesh_Receiver']:
    slice.get_node(name=n).execute("touch ~/.hushlogin", quiet=True)

# %%
# %%bash -s "$SSH_CMD_Vignesh_Source"
# $1 << EOF
# ##############################################
#
# ping -c 5 192.168.1.4
#
# ##############################################
# exit
# EOF
# Out:
# PING 192.168.1.4 (192.168.1.4) 56(84) bytes of data.
# 64 bytes from 192.168.1.4: icmp_seq=1 ttl=63 time=2.06 ms
# 64 bytes from 192.168.1.4: icmp_seq=2 ttl=63 time=0.187 ms
# 64 bytes from 192.168.1.4: icmp_seq=3 ttl=63 time=0.137 ms
# 64 bytes from 192.168.1.4: icmp_seq=4 ttl=63 time=0.148 ms
# 64 bytes from 192.168.1.4: icmp_seq=5 ttl=63 time=0.139 ms
#
# --- 192.168.1.4 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4080ms
# rtt min/avg/max/mdev = 0.137/0.533/2.057/0.761 ms
# Pseudo-terminal will not be allocated because stdin is not a terminal.
# ...

# %% [markdown]
# sudo iperf3 -s -p 80
# iperf3 -c 192.168.1.3 -p 80 -t 60
# sudo apt-get update
# sudo apt-get install tcpdump
# sudo tcpdump host 192.168.1.3 and \(port 80 or \(port ftp-data or ftp\)\)
# sudo tcpdump host 192.168.1.4 and \(port 80 or \(port ftp-data or ftp\)\)

# %%
# %%bash -s "$SSH_CMD_Vignesh_Receiver"
# $1 << EOF
# ##############################################
# # Install Curl
# sudo apt update
# sudo apt install curl -y
#
# # Install Apache (HTTP server)
# sudo apt install apache2 -y
#
# # Install pure-ftpd(FTP server)
# sudo apt install pure-ftpd -y
#
# touch vignesh
#
# echo "Hello, world!" > vignesh
#
# echo "Installation completed successfully."
# ##############################################
# exit
# EOF

# %% [markdown]
# ## SETUP P4 DOCKER

# %% [markdown]
# ### use the switch ssh and do the following commands
# ``` bash
#  vim testscript.sh
# ```
#  type i to insert the below code
#
# ``` bash
# #!/bin/bash
# #{
# #port1_iface=$1
# #port2_iface=$2
# #port3_iface=$3
# #ip_type=$4
#
# ip_type=$1
# # args="${@:2:2}"
# ifaces="${@:2}"
# # export http_proxy=socks5h://localhost:4567
# # export https_proxy=socks5h://localhost:4567
# echo Hello, FABRIC. From node `hostname -s`
# sudo apt-get update
# sudo apt-get remove -y docker docker-engine docker.io containerd runc
# # install docker engine
# sudo install -m 0755 -d /etc/apt/keyrings
# curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /etc/apt/keyrings/docker.gpg
# sudo chmod a+r /etc/apt/keyrings/docker.gpg
# echo "deb [arch="$(dpkg --print-architecture)" signed-by=/etc/apt/keyrings/docker.gpg] https://download.docker.com/linux/ubuntu "$(. /etc/os-release && echo "$VERSION_CODENAME")" stable" | sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
# sudo apt-get -y update
# sudo apt-get install -y docker-ce docker-ce-cli containerd.io docker-buildx-plugin docker-compose-plugin
# # docker run -d -it --cap-add=NET_ADMIN --privileged --name fabric_p4 pruth/fabric-images:fabric_p4_simple_router
#
# if [ $ip_type = 'IPv4' ]
# then
#   docker run -d -it --cap-add=NET_ADMIN --privileged --name fabric_p4 registry.ipv4.docker.com/pruth/fabric-images:0.0.2j
# else
#   docker run -d -it --cap-add=NET_ADMIN --privileged --name fabric_p4 registry.ipv6.docker.com/pruth/fabric-images:0.0.2j
#   sed -i '/nameserver/d' /etc/resolv.conf
#   echo nameserver 2a00:1098:2c::1 >> /etc/resolv.conf
#   echo nameserver 2a01:4f8:c2c:123f::1 >> /etc/resolv.conf
#   echo nameserver 2a00:1098:2b::1 >> /etc/resolv.conf
# fi
#
# sleep 10
# NSPID=$(docker inspect --format='{{ .State.Pid }}' fabric_p4)
# echo NSPID $NSPID
#
# switch_interface_args=""
# swtich_port=0
# for iface in $ifaces; do
#   ip link set dev $iface promisc on
#   ip link set $iface netns $NSPID
#   docker exec fabric_p4 ip link set dev $iface up
#   docker exec fabric_p4 ip link set dev $iface promisc on
#   docker exec fabric_p4 sysctl net.ipv6.conf.${iface}.disable_ipv6=1
#
#   switch_interface_args="${switch_interface_args} --interface ${swtich_port}@${iface}"
#   swtich_port=$((swtich_port+1))
# done
#
#
# echo Starting switch
# #echo simple_switch $switch_interface_args /root/simple_p4_router/simple_router.bmv2/simple_router.json
# #complite
# docker exec -w /root/tutorials/exercises/basic_tunnel fabric_p4 sh -c 'cp basic_tunnel.p4 basic_tunnel.working.p4'
# docker exec -w /root/tutorials/exercises/basic_tunnel fabric_p4 sh -c 'cp solution/basic_tunnel.p4 basic_tunnel.p4'
# docker exec -w /root/tutorials/exercises/basic_tunnel fabric_p4 sh -c 'p4c --p4runtime-files basic_tunnel.txt --target bmv2 --arch v1model basic_tunnel.p4'
# docker exec -d -it fabric_p4 sh -c 'simple_switch --interface 1@'${port1_iface}' --interface 2@'${port2_iface}' --interface 3@'${port3_iface}' /root/tutorials/exercises/basic_tunnel/basic_tunnel.json'
# #docker exec -it fabric_p4 simple_switch_CLI
# #sudo sh -c 'cat commands.txt | docker exec -i fabric_p4 simple_switch_CLI --thrift-port 9090
# #sudo sh -c 'echo table_dump myTunnel_exact | docker exec -i fabric_p4 simple_switch_CLI --thrift-port 9090 '
#
# echo done!
# #} 2>&1 > /tmp/script.log
# ```
# save and quit
# using esc, :wq
#
# use chmod 750 testscript.sh to make it executable
# run sudo ./testscript.sh 2001:400:a100:3000:f816:3eff:fec7:5ebb ens7 ens8 ens9
#                                management ip (example)
# please use the management ip of the switch

# %% [markdown]
# net0_name = 'net0'
# net1_name = 'net1'
# net2_name = 'net2'
# switch1 = slice.get_node('switch1')
# s1_h1_os_iface = switch1.get_interface(network_name=net0_name)
# s1_s2_os_iface = switch1.get_interface(network_name=net1_name)
# s1_s3_os_iface = switch1.get_interface(network_name=net2_name)
# if type(ip_address(switch1.get_management_ip())) is IPv4Address:
#         management_ip_type = "IPv4"
# else:
#         management_ip_type = "IPv6"
# # Upload the file to the switch1 node and execute it
# file_attributes = switch1.upload_file('/home/fabric/work/jupyter-examples-rel1.4.2/fabric_examples/complex_recipes/P4_bmv2/scripts/router_setup_p4_bmv2_container.sh','router_setup_p4_bmv2_container.sh')
# command=f"chmod +x router_setup_p4_bmv2_container.sh && sudo sh -c '/home/fabric/work/jupyter-examples-rel1.4.2/fabric_examples/complex_recipes/P4_bmv2/scripts/router_setup_p4_bmv2_container.sh {management_ip_type} {s1_h1_os_iface.get_os_interface()} {s1_s2_os_iface.get_os_interface()} {s1_s3_os_iface.get_os_interface()}  > /tmp/script.log 2>&1'"
# switch1_config = switch1.execute_thread(command)
# try:
#     stdout, stderr = switch1_config.result()
#     print(f"Config thread for node {switch1.get_name()} complete")
#     print(f"stdout: {stdout}")
#     print(f"stderr: {stderr}")
# except Exception as e:
#     print(f"Error: {e}")
#     traceback.print_exc()

# %% [markdown]
# ### Configure Table

# %%
switch1 = slice.get_node('switch1')
management_ip_switch = str(switch1.get_management_ip())
print("Switch Name        : {}".format(switch1.get_name()))
print("Management IP    : {}".format(management_ip_switch))

#Configure P4 Tables
file_attributes = switch1.upload_file('/home/fabric/work/jupyter-examples/fabric_examples/complex_recipes/P4_bmv2/scripts/switch1_commands.txt','switch1_commands.txt')
print("file_attributes: {}".format(file_attributes))
cmd_file='switch1_commands.txt'
stdout = switch1.execute("sudo sh -c 'cat switch1_commands.txt | docker exec -i fabric_p4 simple_switch_CLI'")
print("stdout: {}".format(stdout))
# Out:
# Switch Name        : switch1
# Management IP    : 2001:400:a100:3000:f816:3eff:fedf:3c6c
# file_attributes: -rw-rw-r--   1 1000     1000           97 28 Apr 18:16 ?
# Obtaining JSON from switch...
# Done
# Control utility for runtime P4 table manipulation
# RuntimeCmd: Setting default action of myTunnel_exact
# action:              drop
# runtime data:
# RuntimeCmd: Error: Table myTunnel_exact needs 1 key fields
# RuntimeCmd: Error: Table myTunnel_exact needs 1 key fields
# RuntimeCmd: Error: Table myTunnel_exact needs 1 key fields
# RuntimeCmd: Error: Table myTunnel_exact needs 1 key fields
# RuntimeCmd:
# ...

# %% [markdown]
# ### DELETE A SLICE

# %%
fablib.delete_slice(SLICENAME)
